# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import seaborn as sns

plt.rcParams['figure.figsize'] = [20, 15]
df = pd.read_csv('filtered.txt', sep='\t')

df = df.iloc[:, 1:]

df.set_index('time')
# Out:
#                from        to
# time
# 15.032877  KYY--Y1x  KYY--Y2x
# 15.060274  KNFNFY1x  KNFNFY2x
# 15.063014  KNF--Y1x  KNF--Y2x
# 15.079452  KNYNYY1x  KNYNYY2x
# 15.098630  KNF--Y1x  KNF--Y2x
# 15.106849  KNF--Y1x  KNF--Y2x
# 15.106849  KNY--Y1x  KNY--Y2x
# 15.115068  TNY--Y1x  TNY--Y2x
# 15.128767  KYY--Y1x  KYY--Y2x
# 15.147945  KYF--Y1x  KYF--Y2x
# 15.147945  KNF--Y1x  KNF--Y2x
# 15.164384  KYY--Y1x  KYY--Y2x
# 15.169863  TNY--Y1x  TNY--Y2x
# 15.183562  KNY--Y1x  KNY--Y2x
# 15.186301  KNYNYY1x  KNYNYY2x
# 15.197260  KNF--Y1x  KNF--Y2x
# 15.252055  KYY--Y1x  KYY--Y2x
# 15.252055  KNYNYY1x  KNYNYY2x
# 15.265753  TNY--Y1x  TNY--Y2x
# 15.282192  KNYNYY1x  KNYNYY2x
# 15.282192  TYY--Y1x  TYY--Y2x
# 15.284932  KNY--Y1x  KNY--Y2x
# 15.295890  KYF--Y1x  KYF--Y2x
# 15.309589  KNF--Y1x  KNF--Y2x
# 15.317808  KNFNFY1x  KNFNFY2x
# 15.320548  TNY--Y1x  TNY--Y2x
# 15.328767  KYF--Y1x  KYF--Y2x
# 15.350685  KNF--Y1x  KNF--Y2x
# 15.361644  KYFYFY1x  KYFYFY2x
# 15.369863  KNF--Y1x  KNF--Y2x
# ...             ...       ...
# 39.994521  KYYYYY2x  TYYYYY2x
# 39.994521  KYYYYY2x  TYYYYY2x
# 39.997260  KNYNYY2x  TNYNYY2x
# 40.000000  KNYNYY2x  TNYNYY2x
# 40.005479  TYYYYY2x  KYYYYY2x
# 40.005479  KYYYYY2x  TYYYYY2x
# 40.005479  KYYYYY2x  TYYYYY2x
# 40.008219  TYYYYY2x  KYYYYY2x
# 40.010959  TYYYYY2x  KYYYYY2x
# 40.013699  TYYYYY2x  KYYYYY2x
# 40.013699  TYYYYY2x  KYYYYY2x
# 40.016438  TYYYYY2x  KYYYYY2x
# 40.016438  TYYYYY2x  KYYYYY2x
# 40.016438  TYYYYY2x  KYYYYY2x
# 40.016438  TYYYYY2x  KYYYYY2x
# 40.016438  TYYYYY2x  KYYYYY2x
# 40.016438  TYYYYY2x  KYYYYY2x
# 40.016438  KYYYYY2x  TYYYYY2x
# 40.016438  KYYYYY2x  TYYYYY2x
# 40.019178  TYYYYY2x  KYYYYY2x
# 40.019178  TYYYYY2x  KYYYYY2x
# 40.019178  TNYNYY2x  KNYNYY2x
# 40.021918  KYYYYY2x  TYYYYY2x
# 40.021918  TNYNYY2x  KNYNYY2x
# 40.021918  TYYYYY2x  KYYYYY2x
# 40.021918  KYYYYY2x  TYYYYY2x
# 40.024658  TYYYYY2x  KYYYYY2x
# 40.024658  TYYYYY2x  KYYYYY2x
# 40.027397  TYYYYY2x  KYYYYY2x
# 40.027397  TYYYYY2x  KYYYYY2x
#
# [6464 rows x 2 columns]

# %%
df2 = df.groupby('time').count()

# %%
plt.hist(df2['to'], edgecolor='black')
#plt.plot(df2['to'])
# Out:
# (array([1.902e+03, 7.560e+02, 3.360e+02, 1.950e+02, 1.040e+02, 5.200e+01,
#         3.300e+01, 1.800e+01, 5.000e+00, 1.000e+00]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(df2['to', hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
