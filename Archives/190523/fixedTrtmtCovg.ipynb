# %%
# running sim by using the same treatment converage but diff strategy

# %%
import matplotlib.pyplot as plt
import csv

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %%
# using t.c. rate of 0.6

# %%
x1 = []
y1 = []
with open('ft1.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(float(row[0]))
        y1.append(float(row[12]))
x1 = [i/365 for i in x1]

# %%
x2 = []
y2 = []
with open('ft2.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x2.append(float(row[0]))
        y2.append(float(row[12]))
x2 = [i/365 for i in x2]

# %%
x3 = []
y3 = []
with open('ft3.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x3.append(float(row[0]))
        y3.append(float(row[12]))
x3 = [i/365 for i in x3]

# %%
x4 = []
y4 = []
with open('ft4.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x4.append(float(row[0]))
        y4.append(float(row[12]))
x4 = [i/365 for i in x4]

# %%
plt.plot(x1,y1,'g') # green line for AL-SFT (#1)
plt.plot(x2,y2,'r') # red for Cycling (#3)
plt.plot(x3,y3,'c') # cyan line for Adaptive Cycling (#4)
plt.plot(x4,y4,'m') # magneta line for MFT (#5)
plt.show()
