# %%
# running sim by using the same strategy but diff treatment converage

# %%
import matplotlib.pyplot as plt
import csv

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %%
# using strategy #3, cycling

# %%
x0 = []
y0 = []
with open('fs0.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x0.append(float(row[0]))
        y0.append(float(row[12]))
x0 = [i/365 for i in x0]

# %%
x1 = []
y1 = []
with open('fs1.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(float(row[0]))
        y1.append(float(row[12]))
x1 = [i/365 for i in x1]

# %%
x2 = []
y2 = []
with open('fs2.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x2.append(float(row[0]))
        y2.append(float(row[12]))
x2 = [i/365 for i in x2]

# %%
x3 = []
y3 = []
with open('fs3.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x3.append(float(row[0]))
        y3.append(float(row[12]))
x3 = [i/365 for i in x3]

# %%
x4 = []
y4 = []
with open('fs4.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x4.append(float(row[0]))
        y4.append(float(row[12]))
x4 = [i/365 for i in x4]

# %%
plt.plot(x0,y0,'b') # blue line for t.c.=0.1
plt.plot(x1,y1,'g') # green for t.c.=0.3
plt.plot(x2,y2,'r') # red line for t.c.=0.5
plt.plot(x3,y3,'c') # cyan line for t.c.=0.7
plt.plot(x4,y4,'m') # megneta line for t.c.=0.9
plt.show()
